# %%
idade = int(input("digite sua idade:"))
carro = input("tem carro? <s/n>")  
if (idade >= 18) and (carro == "s"):
    print("pode dirigir!")
else: 
    print("chama o uber!!")
# Out:
# digite sua idade: 77
# tem carro? <s/n> n
# chama o uber!!

# %%
nota1 = float(input("digite a nota 1:"))
nota2 = float(input("digite a nota 2:"))
media = (nota1 + nota2 / 2)
if media >= 5:
    print("A MÉDIA É IGUAL A:", media)
    print("APROVADO(A)!")
else: 
    print("REPROVADO(A)!")
# Out:
# digite a nota 1: 9
# digite a nota 2: 7
# A MÉDIA É IGUAL A: 12.5
# APROVADO(A)!

# %%
nota1 = float(input("digite a nota 1:"))
if nota1 >7:
    nota1 = nota1 + 0.5
nota2 = float(input("digite a nota 2:"))
if nota2 >7:
    nota2 = nota2 + 0.5
media = (nota1 + nota2)/ 2
if media >= 5:
    print("A MÉDIA É IGUAL A:", media)
    print("APROVADO(A)!")
else: 
    print("REPROVADO(A)!")
# Out:
# digite a nota 1: 8
# digite a nota 2: 8
# A MÉDIA É IGUAL A: 8.5
# APROVADO(A)!

# %%
print("digite os lados de um triangulo:")
a = float(input("entre com o lado a: "))
b = float(input("entre com o lado b: "))
c = float(input("entre com o lado c: "))
if (a >= b+c) or (b >= a+c) or (c >= a+b):
    print("não é um triangulo")
else:
    if (a == b == c):
        print("triangulo equilatero")
    elif (a == b) or (b == c) or (a == c):
        print("triangulo isoceles")
    else:
       print("triangulo escaleno")
# Out:
# digite os lados de um triangulo:
# entre com o lado a:  9
# entre com o lado b:  9
# entre com o lado c:  4
# triangulo isoceles
