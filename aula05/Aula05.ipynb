# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ((3 * y)/(5 * y + 7)) + 2 * y
#
# NameError: name 'y' is not defined

# %% [markdown]
# calculo da area

# %%
base = float(input("digite a base:"))
altura = float(input("digite a altura:"))
area = base * altura 
print (" A area do equilatero é:", area)
# Out:
# digite a base: 80
# digite a altura: 30
#  A area do equilatero é: 2400.0
