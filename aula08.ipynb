# %%
import random

# %%
numero_sorteado = random.randint(1,50)

# %%
print (n)
# Out:
# 13

# %%
while True: 
    numero_usuario = int(input("digite um numero de 1 a 50"))
    if numero_usuario == numero_sorteado:
        print ("parabéns!!")
        break
    elif numero_usuario < numero_sorteado:
        print("é maior!!")
    else 
        print("é menor!!")
# Out:
#   Cell In[10], line 8
#     else
#          ^
# SyntaxError: expected ':'

# %% [markdown]
# ### import random
#
# numero_sorteado = random.randint(1, 50)
#
# for i in range(5):
#     numero_usuario = int(input("Digite um número: "))
#
#     if numero_usuario == numero_sorteado:
#         print("Parabéns!!")
#         break
#     elif numero_usuario < numero_sorteado:
#         print("É maior!!")
#     else:
#         print("É menor!!")

# %% [markdown]
# #### import random
#
# numero_sorteado = random.randint(1, 50)
#
# for i in range(1000):
#     numero_usuario = int(input("Digite um número: "))
#
#     if numero_usuario == numero_sorteado:
#         print("Parabéns!!")
#         break
#     elif numero_usuario < numero_sorteado:
#         print("É maior!!")
#     else:
#         print("É menor!!")

# %%
import random

numero_sorteado = random.randint(1, 50)

for i in range(1000):
    numero_usuario = int(input("Digite um número: "))

    if numero_usuario == numero_sorteado:
        print("Parabéns!!")
        break
    elif numero_usuario < numero_sorteado:
        print("É maior!!")
    else:
        print("É menor!!")
# Out:
# Digite um número:  40
# É menor!!
# Digite um número:  35
# É menor!!
# Digite um número:  10
# É maior!!
# Digite um número:  25
# É maior!!
# Digite um número:  30
# Parabéns!!
